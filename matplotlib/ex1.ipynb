# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1, 2, 3, 4])
print(plt.show())

# %%
plt.plot([4, 5, 6, 7], [1, 4, 9, 16])
print(plt.show())
# Out:
# None

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import numpy as np

t = np.arange(start=0, stop=5, step=0.2)

plt.plot(t, t, 'r--', t, t ** 2, 'bs', t, t ** 3, 'g^')
plt.show()
